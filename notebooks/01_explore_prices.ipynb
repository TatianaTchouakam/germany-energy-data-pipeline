# %%
"""Turn the price sample into a readable table with Berlin time."""
import json
from pathlib import Path

import pandas as pd

data = json.loads(Path("../data/samples/price.json").read_text())
data.keys()
# Out:
# dict_keys(['license_info', 'unix_seconds', 'price', 'unit', 'deprecated'])

# %%
df = pd.DataFrame({
    "unix_seconds": data["unix_seconds"],
    "price_eur_mwh": data["price"],
})
df["timestamp_utc"] = pd.to_datetime(df["unix_seconds"], unit="s", utc=True)
df["timestamp_berlin"] = df["timestamp_utc"].dt.tz_convert("Europe/Berlin")
df.head(10)
# Out:
#    unix_seconds  price_eur_mwh             timestamp_utc  \
# 0    1789855200          18.20 2026-09-19 22:00:00+00:00
# 1    1789856100          16.37 2026-09-19 22:15:00+00:00
# 2    1789857000          14.99 2026-09-19 22:30:00+00:00
# 3    1789857900          13.61 2026-09-19 22:45:00+00:00
# 4    1789858800          14.85 2026-09-19 23:00:00+00:00
# 5    1789859700          13.05 2026-09-19 23:15:00+00:00
# 6    1789860600          12.49 2026-09-19 23:30:00+00:00
# 7    1789861500          11.04 2026-09-19 23:45:00+00:00
# 8    1789862400           8.57 2026-09-20 00:00:00+00:00
# 9    1789863300          11.25 2026-09-20 00:15:00+00:00
#
#            timestamp_berlin
# 0 2026-09-20 00:00:00+02:00
# 1 2026-09-20 00:15:00+02:00
# 2 2026-09-20 00:30:00+02:00
# 3 2026-09-20 00:45:00+02:00
# 4 2026-09-20 01:00:00+02:00
# 5 2026-09-20 01:15:00+02:00
# 6 2026-09-20 01:30:00+02:00
# 7 2026-09-20 01:45:00+02:00
# 8 2026-09-20 02:00:00+02:00
# 9 2026-09-20 02:15:00+02:00

# %%
df.loc[[df["price_eur_mwh"].idxmin(), df["price_eur_mwh"].idxmax()]]
# Out:
#      unix_seconds  price_eur_mwh             timestamp_utc  \
# 54     1789903800          -2.02 2026-09-20 11:30:00+00:00
# 175    1790012700         275.90 2026-09-21 17:45:00+00:00
#
#              timestamp_berlin
# 54  2026-09-20 13:30:00+02:00
# 175 2026-09-21 19:45:00+02:00
